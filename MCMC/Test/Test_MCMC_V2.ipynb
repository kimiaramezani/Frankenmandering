# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install torch_geometric
# Out:
# Requirement already satisfied: torch_geometric in /usr/local/lib/python3.12/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.12.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2025.8.3)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)

# %%
import numpy as np
import torch
from torch_geometric.data import Data
from gymnasium import spaces
from gerry_environment import FrankenmanderingEnv
from graph_initiator import build_init_data
# from report_gen import plot_summary_each_run,pairwise_hamming_mean, plot_summary_global
from MCMC_version2 import mcmc_full_annealing
from drf_funcs import drf_inchworm_withso

# %%
init_data, G_graph = build_init_data()

num_voters = init_data.opinion.shape[0]
num_districts = 4
target_opinion=[7]*num_voters

env_sco = FrankenmanderingEnv(num_voters=num_voters,
                          num_districts=num_districts,
                          opinion_dim=1,
                          FrankenData=init_data,
                          target_opinion=target_opinion)
env_sco.reset()
initial_opinion = init_data.opinion

df_summary,env, ensemble_labels, ensemble_rewards,ensemble_opinions, acceptance_rates, global_accept_rate = mcmc_full_annealing(
    env =env_sco ,
    outer_loops = 100,
    hot_steps = 20,
    anneal_steps =80,
    cold_steps = 20,
    T_init = 1,
    T_final = 0.01,
    seed = 42,
    drf = drf_inchworm_withso,
    beta1 = 0.1,
    beta2 = 0.5,
    p_keep = 0.5
)
# Out:
# BA (undirected) edges: 140 (expected m*(N-m) = 2*(72-2) = 140)
# SOC directed arcs: 280 (should be 2 * 140 = 280)
# [Outer step 1/100] best reward = 2.0417, inner acceptance rate = 0.750
# [Outer step 2/100] best reward = 2.9872, inner acceptance rate = 0.683
# [Outer step 3/100] best reward = 3.2670, inner acceptance rate = 0.667
# [Outer step 4/100] best reward = 3.2670, inner acceptance rate = 0.958
# [Outer step 5/100] best reward = 3.2670, inner acceptance rate = 0.717
# [Outer step 6/100] best reward = 3.2670, inner acceptance rate = 0.833
# [Outer step 7/100] best reward = 3.2670, inner acceptance rate = 0.575
# [Outer step 8/100] best reward = 3.6317, inner acceptance rate = 0.642
# [Outer step 9/100] best reward = 1.0911, inner acceptance rate = 0.883
# [Outer step 10/100] best reward = 1.0911, inner acceptance rate = 0.958
# [Outer step 11/100] best reward = 1.0911, inner acceptance rate = 0.783
# [Outer step 12/100] best reward = 1.0911, inner acceptance rate = 0.683
# [Outer step 13/100] best reward = 0.4733, inner acceptance rate = 0.692
# [Outer step 14/100] best reward = 0.4733, inner acceptance rate = 0.950
# [Outer step 15/100] best reward = 0.4733, inner acceptance rate = 0.800
# [Outer step 16/100] best reward = 1.5025, inner acceptance rate = 0.700
# [Outer step 17/100] best reward = 1.5025, inner acceptance rate = 0.992
# [Outer step 18/100] best reward = 0.4012, inner acceptance rate = 0.983
# [Outer step 19/100] best reward = -0.3259, inner acceptance rate = 0.942
# [Outer step 20/100] best reward = 0.8056, inner acceptance rate = 0.883
# [Outer step 21/100] best reward = 0.3412, inner acceptance rate = 0.908
# [Outer step 22/100] best reward = 0.3412, inner acceptance rate = 0.742
# [Outer step 23/100] best reward = -1.3039, inner acceptance rate = 0.967
# [Outer step 24/100] best reward = -1.3565, inner acceptance rate = 0.792
# [Outer step 25/100] best reward = -1.3565, inner acceptance rate = 0.400
# [Outer step 26/100] best reward = -1.3565, inner acceptance rate = 0.908
# [Outer step 27/100] best reward = -1.3565, inner acceptance rate = 0.842
# [Outer step 28/100] best reward = -1.3644, inner acceptance rate = 0.783
# [Outer step 29/100] best reward = -1.3644, inner acceptance rate = 0.817
# [Outer step 30/100] best reward = -1.3644, inner acceptance rate = 0.767
# [Outer step 31/100] best reward = -1.3644, inner acceptance rate = 0.717
# [Outer step 32/100] best reward = -1.0350, inner acceptance rate = 0.942
# [Outer step 33/100] best reward = 0.6763, inner acceptance rate = 0.733
# [Outer step 34/100] best reward = 0.6763, inner acceptance rate = 0.850
# [Outer step 35/100] best reward = 0.6814, inner acceptance rate = 0.925
# [Outer step 36/100] best reward = 0.6814, inner acceptance rate = 0.750
# [Outer step 37/100] best reward = 0.6814, inner acceptance rate = 0.833
# [Outer step 38/100] best reward = 0.4291, inner acceptance rate = 0.867
# [Outer step 39/100] best reward = 1.5747, inner acceptance rate = 0.675
# [Outer step 40/100] best reward = 1.5747, inner acceptance rate = 0.958
# [Outer step 41/100] best reward = -0.7729, inner acceptance rate = 0.842
# [Outer step 42/100] best reward = 1.2470, inner acceptance rate = 0.692
# [Outer step 43/100] best reward = 0.0509, inner acceptance rate = 0.950
# [Outer step 44/100] best reward = 0.0509, inner acceptance rate = 0.775
# [Outer step 45/100] best reward = -0.3578, inner acceptance rate = 0.500
# [Outer step 46/100] best reward = -0.3578, inner acceptance rate = 0.892
# [Outer step 47/100] best reward = -1.9693, inner acceptance rate = 0.842
# [Outer step 48/100] best reward = -1.9693, inner acceptance rate = 0.875
# [Outer step 49/100] best reward = -1.9693, inner acceptance rate = 0.833
# [Outer step 50/100] best reward = -1.6371, inner acceptance rate = 0.008
# [Outer step 51/100] best reward = -1.6371, inner acceptance rate = 0.917
# [Outer step 52/100] best reward = -1.6371, inner acceptance rate = 0.983
# [Outer step 53/100] best reward = -1.6371, inner acceptance rate = 0.942
# [Outer step 54/100] best reward = -1.6371, inner acceptance rate = 0.750
# [Outer step 55/100] best reward = 1.3128, inner acceptance rate = 0.767
# [Outer step 56/100] best reward = 0.1739, inner acceptance rate = 0.750
# [Outer step 57/100] best reward = -0.7206, inner acceptance rate = 0.942
# [Outer step 58/100] best reward = 0.9505, inner acceptance rate = 0.925
# [Outer step 59/100] best reward = -0.7234, inner acceptance rate = 0.917
# [Outer step 60/100] best reward = -1.3504, inner acceptance rate = 0.842
# [Outer step 61/100] best reward = -2.4841, inner acceptance rate = 0.008
# [Outer step 62/100] best reward = -2.4841, inner acceptance rate = 0.758
# [Outer step 63/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 64/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 65/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 66/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 67/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 68/100] best reward = -2.5243, inner acceptance rate = 0.958
# [Outer step 69/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 70/100] best reward = -2.5243, inner acceptance rate = 0.008
# [Outer step 71/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 72/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 73/100] best reward = -2.7232, inner acceptance rate = 0.925
# [Outer step 74/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 75/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 76/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 77/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 78/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 79/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 80/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 81/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 82/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 83/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 84/100] best reward = -2.7232, inner acceptance rate = 0.783
# [Outer step 85/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 86/100] best reward = -2.7232, inner acceptance rate = 0.858
# [Outer step 87/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 88/100] best reward = -2.7232, inner acceptance rate = 0.950
# [Outer step 89/100] best reward = -2.7232, inner acceptance rate = 0.008
# [Outer step 90/100] best reward = -2.6577, inner acceptance rate = 0.942
# [Outer step 91/100] best reward = -2.6577, inner acceptance rate = 0.008
# [Outer step 92/100] best reward = -2.6577, inner acceptance rate = 0.667
# [Outer step 93/100] best reward = -2.6577, inner acceptance rate = 0.933
# [Outer step 94/100] best reward = -2.6577, inner acceptance rate = 0.008
# [Outer step 95/100] best reward = -2.6577, inner acceptance rate = 0.883
# [Outer step 96/100] best reward = -2.6577, inner acceptance rate = 0.925
# [Outer step 97/100] best reward = -3.2727, inner acceptance rate = 0.008
# [Outer step 98/100] best reward = -3.2727, inner acceptance rate = 0.933
# [Outer step 99/100] best reward = -3.2727, inner acceptance rate = 0.975
# [Outer step 100/100] best reward = -3.2727, inner acceptance rate = 0.008
#
# Total proposed: 12000, accepted: 7189, overall acceptance rate: 0.599

# %%
df_summary.to_csv('output.csv', index=False)

# %%
def reward_improvement(df):
    """Return mean improvement from min to best reward."""
    improvement = df['reward_best'] - df['reward_best'].min()
    return improvement.mean(), improvement.std()

# %%
def mean_opinion_change(df):
    """Return mean and std of opinion change magnitude."""
    delta = df['last_mean_opinin'] - df['initial_mean_opinin']
    return delta.mean(), delta.std()

# %%
# def dist_from_initial(df):
#     """Compute Euclidean distance between best and initial opinions."""
#     distances = []
#     for i, row in df.iterrows():
#         best_op = np.array(row['best_opinion'])
#         init_op = np.array(row['initial_mean_opinin'])
#         distances.append(np.linalg.norm(best_op - init_op))
#     return np.mean(distances), np.std(distances)

# %%
def dist_from_initial(df):
    """Euclidean distance per step between initial and best opinions (per-agent)."""
    distances = []
    for _, row in df.iterrows():
        init_op = np.array(initial_opinion)
        best_op = np.array(row['best_opinion'])
        d = np.linalg.norm(best_op - init_op)
        distances.append(d)
    return np.mean(distances), np.std(distances)

# %%
def calc_best_reward(df):
    """Return the maximum best reward achieved across all runs."""
    return df['reward_best'].max()

# %%
def mean_change_each_step(df):
    """Mean absolute per-agent change from initial to best opinion per step."""
    changes = []
    for _, row in df.iterrows():
        init_op = np.array(initial_opinion)
        best_op = np.array(row['best_opinion'])
        diff = np.abs(best_op - init_op)
        changes.append(np.mean(diff))
    return np.mean(changes), np.std(changes)

# %%
# def mean_change_each_step(df):

#   best_op_mean = df['best_opinion'].apply(lambda x: np.mean(x) if isinstance(x, (list, np.ndarray)) else x)
#   total_mean = abs(df['initial_mean_opinin'] - best_op_mean)

#   return total_mean

# %%
def summarize_mcmc_results(df):
    summary = {}
    # summary['acceptance_rate'] = df['accepted_step_rate'].mean()
    summary['opinion_change_mean'], summary['opinion_change_std'] = mean_opinion_change(df)
    summary['dist_from_initial_mean'], summary['dist_from_initial_std'] = dist_from_initial(df)
    summary['best_reward'] = calc_best_reward(df)
    summary['mean_reward'] = df['reward_best'].mean()
    summary['mean_shift_step'] = mean_change_each_step(df)

    return summary

# %%
summary = summarize_mcmc_results(df_summary)
print("=== GLOBAL MCMC SUMMARY ===")
for key, val in summary.items():
    print(f"{key:30s}: {val:.4f}" if isinstance(val, (float, np.floating)) else f"{key:30s}: {val}")
# Out:
# === GLOBAL MCMC SUMMARY ===
# opinion_change_mean           : -0.0107
# opinion_change_std            : 0.0264
# dist_from_initial_mean        : 131.2301
# dist_from_initial_std         : 0.6379
# best_reward                   : 3.6317
# mean_reward                   : -0.9409
# mean_shift_step               : (np.float64(1.4800139659781149), np.float64(0.007102361595036212))

# %%
import matplotlib.pyplot as plt

def plot_grouped_opinion_bar(opinions_sequence, title="Opinion Distribution per Run"):
    """
    Plot all opinions per run as grouped bars.

    :param title: chart title
    """
    num_runs = len(opinions_sequence)
    num_ops = opinions_sequence[0].shape[0]

    # Flatten vector opinions to scalar by averaging if needed
    opinions_flat = [op.mean(axis=1) if op.ndim > 1 else op for op in opinions_sequence]

    # Prepare data for grouped bars
    x = np.arange(num_runs)  # runs on x-axis
    width = 0.8 / num_ops  # width of each bar within group

    plt.figure(figsize=(max(8, num_runs), 5))

    for i in range(num_ops):
        agent_values = [opinions_flat[run][i] for run in range(num_runs)]
        plt.bar(x + i*width, agent_values, width=width, label="")

    plt.xlabel("Run")
    plt.ylabel("Opinion Value")
    plt.title(title)
    plt.xticks(x + width*(num_ops-1)/2, [f"Run {i+1}" for i in range(num_runs)])
    plt.legend()
    plt.show()

# %%
# save_path = "/content/drive/My Drive/scale_test"

# %%
# Plot histograms
plot_grouped_opinion_bar(ensemble_opinions)
# Out:
# /tmp/ipython-input-455693182.py:29: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

def plot_stacked_bar(df, step_col, opinion_col, opinion_range):
    grouped = df.groupby('step')['best_opinion'].sum()  # concatenates lists
    counts = []
    for step, opinions in grouped.items():
        # Round each float to int
        opinions_int = [int(round(x)) for x in opinions]
        c = Counter(opinions_int)
        row = [c.get(i, 0) for i in range(min(opinions_int), max(opinions_int)+1)]
        counts.append(row)
    print('counts',counts)
    # Convert to DataFrame
    count_df = pd.DataFrame(counts,
                            index=grouped.index,
                            columns=[str(i) for i in opinion_range])

    # Normalize to proportions (optional, remove if you want raw counts)
    # count_df = count_df.div(count_df.sum(axis=1), axis=0)
    # Plot stacked bar
    count_df.plot(kind='bar', stacked=True, figsize=(8, 5), cmap='tab20')
    plt.title('Stacked Distribution of Opinion by Stef')
    plt.xlabel('Step')
    plt.ylabel('Opinion Values')
    plt.legend(title='Opinion', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    # plt.savefig(save_path)
    plt.show()

# %%
all_opinions = [num for sublist in df_summary['best_opinion'] for num in sublist]

# Calculate range
op_max =max(all_opinions)
op_min = min(all_opinions)

# %%
# Call the function
plot_stacked_bar(df_summary,
                 step_col='step',
                 opinion_col='best_opinion',
                 opinion_range=range(int(op_min)-1, int(op_max)+1))
# Out:
# counts [[3, 13, 21, 21, 10, 4], [3, 13, 21, 21, 10, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 15, 21, 22, 9, 3, 1], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 21, 11, 3], [1, 18, 18, 21, 11, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 24, 8, 3], [2, 17, 18, 23, 9, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 22, 10, 3], [1, 18, 18, 21, 11, 3], [1, 18, 18, 21, 11, 3], [1, 19, 17, 22, 10, 3], [3, 15, 19, 23, 8, 3, 1], [3, 15, 19, 24, 7, 4], [3, 15, 19, 24, 7, 4], [3, 16, 18, 23, 9, 3], [3, 16, 18, 23, 9, 3], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 17, 16, 23, 11, 2], [3, 14, 20, 23, 8, 3, 1], [3, 16, 18, 22, 10, 3], [3, 16, 18, 23, 9, 3], [3, 17, 17, 22, 10, 3], [3, 16, 18, 23, 9, 3], [3, 17, 17, 24, 8, 3], [3, 17, 16, 24, 10, 2], [3, 17, 16, 24, 10, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 16, 18, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 24, 9, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 23, 10, 2], [3, 17, 17, 25, 8, 1, 1], [3, 17, 17, 25, 8, 1, 1], [3, 17, 17, 25, 8, 1, 1], [3, 17, 17, 25, 8, 1, 1]]

# %%
def plot_line(xs, ys, xlabel, ylabel, title):
    plt.figure(figsize=(6, 3.5))
    plt.plot(xs, ys, marker='o', linestyle='-', color='C0')
    plt.xticks(xs, xs + 1)  # assuming xs are 0-indexed run_ids
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(alpha=0.25)

    # annotate each point
    for x, y in zip(xs, ys):
        offset = 0.01 * (np.max(ys) - np.min(ys) if np.max(ys)!=np.min(ys) else 1.0)
        yloc = y + offset if y >= 0 else y - offset
        plt.text(x, yloc, f"{y:.3f}", ha='center', va='bottom' if y>=0 else 'top', fontsize=8)

    plt.tight_layout()
    # plt.savefig(save_path)
    plt.show()

# %%
xs = np.arange(len(df_summary))
ys = df_summary['reward_best']

# %%
plot_line(xs,ys,
          "step", 'best reward', 'reward trajectory')
